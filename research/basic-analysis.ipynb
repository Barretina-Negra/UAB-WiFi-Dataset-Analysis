# %% [markdown]
# # 🏴‍☠️ UAB THE HACK! 2025 - WiFi Dataset Analysis
# ## Nivel 1: ROOKIE - Análisis Básico
#
# **Objetivo:** Explorar y visualizar el dataset de WiFi de la UAB
#
# **Dataset:**
# - Access Points (APs): 2,333 archivos con snapshots de APs del campus
# - Clientes: 3,199 archivos con dispositivos conectados
# - Período: Abril-Julio 2025
#
# ---

# %% [markdown]
# ## 📦 1. Importar Librerías
#
# Primero, importamos las librerías necesarias para el análisis.

# %%
# Librerías estándar y científicas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings

# Configuración general
warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid", palette="pastel")
plt.rcParams.update({
    "figure.figsize": (12, 6),
    "axes.titlesize": 18,
    "axes.labelsize": 14
})

# Carga de funciones personalizadas
from utils.data_loader import (
    load_aps,
    load_clients,
    print_dataset_summary,
    get_top_aps
)

print("✅ Librerías y utilidades cargadas correctamente")
# Out:
# ✅ Librerías y utilidades cargadas correctamente

# %% [markdown]
# ## 📂 2. Cargar Datos
#
# Cargamos una muestra del dataset. Empezaremos con 10 archivos para exploración rápida.
#
# **Nota:** Para cargar TODO el dataset, cambia `max_files=None`

# %%
# Cargar Access Points (primeros 10 archivos)
df_aps = load_aps(
    data_dir="../realData/ap",
    max_files=None,
    verbose=True
)

print("\n" + "="*60)
print(f"🎯 APs cargados: {len(df_aps):,} registros")
print("="*60)
# Out:
# 📁 Encontrados 964 archivos en ../realData/ap
# 📊 Cargando todos archivos...
#    Procesados 10/964 archivos... (11280 registros)
#    Procesados 20/964 archivos... (22560 registros)
#    Procesados 30/964 archivos... (33834 registros)
#    Procesados 40/964 archivos... (45119 registros)
#    Procesados 50/964 archivos... (56409 registros)
#    Procesados 60/964 archivos... (67699 registros)
#    Procesados 70/964 archivos... (79003 registros)
#    Procesados 80/964 archivos... (90319 registros)
#    Procesados 90/964 archivos... (101630 registros)
#    Procesados 100/964 archivos... (112940 registros)
#    Procesados 110/964 archivos... (124250 registros)
#    Procesados 120/964 archivos... (135593 registros)
#    Procesados 130/964 archivos... (147013 registros)
#    Procesados 140/964 archivos... (158433 registros)
#    Procesados 150/964 archivos... (169853 registros)
#    Procesados 160/964 archivos... (181273 registros)
#    Procesados 170/964 archivos... (192693 registros)
#    Procesados 180/964 archivos... (204113 registros)
#    Procesados 190/964 archivos... (215533 registros)
#    Procesados 200/964 archivos... (226953 registros)
#    Procesados 210/964 archivos... (238373 registros)
#    Procesados 220/964 archivos... (249793 registros)
#    Procesados 230/964 archivos... (261213 registros)
#    Procesados 240/964 archivos... (272633 registros)
#    Procesados 250/964 archivos... (284053 registros)
#    Procesados 260/964 archivos... (295473 registros)
#    Procesados 270/964 archivos... (306893 registros)
#    Procesados 280/964 archivos... (318313 registros)
#    Procesados 290/964 archivos... (329733 registros)
#    Procesados 300/964 archivos... (341153 registros)
#    Procesados 310/964 archivos... (352573 registros)
#    Procesados 320/964 archivos... (363993 registros)
#    Procesados 330/964 archivos... (375413 registros)
#    Procesados 340/964 archivos... (386833 registros)
#    Procesados 350/964 archivos... (398253 registros)
#    Procesados 360/964 archivos... (409673 registros)
#    Procesados 370/964 archivos... (421093 registros)
#    Procesados 380/964 archivos... (432513 registros)
#    Procesados 390/964 archivos... (443933 registros)
#    Procesados 400/964 archivos... (455353 registros)
#    Procesados 410/964 archivos... (466773 registros)
#    Procesados 420/964 archivos... (478193 registros)
#    Procesados 430/964 archivos... (489613 registros)
#    Procesados 440/964 archivos... (501033 registros)
#    Procesados 450/964 archivos... (512453 registros)
#    Procesados 460/964 archivos... (523873 registros)
#    Procesados 470/964 archivos... (535293 registros)
#    Procesados 480/964 archivos... (546713 registros)
#    Procesados 490/964 archivos... (558133 registros)
#    Procesados 500/964 archivos... (569553 registros)
#    Procesados 510/964 archivos... (580973 registros)
#    Procesados 520/964 archivos... (592393 registros)
#    Procesados 530/964 archivos... (603813 registros)
#    Procesados 540/964 archivos... (615233 registros)
#    Procesados 550/964 archivos... (626653 registros)
#    Procesados 560/964 archivos... (638073 registros)
#    Procesados 570/964 archivos... (649493 registros)
#    Procesados 580/964 archivos... (660913 registros)
#    Procesados 590/964 archivos... (672333 registros)
#    Procesados 600/964 archivos... (683753 registros)
#    Procesados 610/964 archivos... (695173 registros)
#    Procesados 620/964 archivos... (706593 registros)
#    Procesados 630/964 archivos... (718013 registros)
#    Procesados 640/964 archivos... (729433 registros)
#    Procesados 650/964 archivos... (740853 registros)
#    Procesados 660/964 archivos... (752273 registros)
#    Procesados 670/964 archivos... (763693 registros)
#    Procesados 680/964 archivos... (775113 registros)
#    Procesados 690/964 archivos... (786533 registros)
#    Procesados 700/964 archivos... (797953 registros)
#    Procesados 710/964 archivos... (809373 registros)
#    Procesados 720/964 archivos... (820793 registros)
#    Procesados 730/964 archivos... (832213 registros)
#    Procesados 740/964 archivos... (843633 registros)
#    Procesados 750/964 archivos... (855053 registros)
#    Procesados 760/964 archivos... (866473 registros)
#    Procesados 770/964 archivos... (877893 registros)
#    Procesados 780/964 archivos... (889313 registros)
#    Procesados 790/964 archivos... (900733 registros)
#    Procesados 800/964 archivos... (912153 registros)
#    Procesados 810/964 archivos... (923573 registros)
#    Procesados 820/964 archivos... (934993 registros)
#    Procesados 830/964 archivos... (946413 registros)
#    Procesados 840/964 archivos... (957833 registros)
#    Procesados 850/964 archivos... (969253 registros)
#    Procesados 860/964 archivos... (980673 registros)
#    Procesados 870/964 archivos... (992093 registros)
#    Procesados 880/964 archivos... (1003513 registros)
#    Procesados 890/964 archivos... (1014933 registros)
#    Procesados 900/964 archivos... (1026353 registros)
#    Procesados 910/964 archivos... (1037773 registros)
#    Procesados 920/964 archivos... (1049193 registros)
#    Procesados 930/964 archivos... (1060613 registros)
#    Procesados 940/964 archivos... (1072033 registros)
#    Procesados 950/964 archivos... (1083453 registros)
#    Procesados 960/964 archivos... (1094873 registros)
# ✅ Cargados 1099441 registros de 964 archivos
# 💾 Memoria: 1463.47 MB
#
# ============================================================
# 🎯 APs cargados: 1,099,441 registros
# ============================================================

# %%
# Cargar Clientes (primeros 10 archivos)
df_clients = load_clients(
    data_dir="../realData/clients",
    max_files=None,
    verbose=True
)

print("\n" + "="*60)
print(f"🎯 Clientes cargados: {len(df_clients):,} registros")
print("="*60)
# Out:
# 📁 Encontrados 299 archivos en ../realData/clients
# 📊 Cargando todos archivos...
#    Procesados 10/299 archivos... (15581 registros)
#    Procesados 20/299 archivos... (129244 registros)
#    Procesados 30/299 archivos... (260458 registros)
#    Procesados 40/299 archivos... (328976 registros)
#    Procesados 50/299 archivos... (338274 registros)
#    Procesados 60/299 archivos... (422585 registros)
#    Procesados 70/299 archivos... (538256 registros)
#    Procesados 80/299 archivos... (601490 registros)
#    Procesados 90/299 archivos... (610072 registros)
#    Procesados 100/299 archivos... (622502 registros)
#    Procesados 110/299 archivos... (632273 registros)
#    Procesados 120/299 archivos... (640807 registros)
#    Procesados 130/299 archivos... (651676 registros)
#    Procesados 140/299 archivos... (660169 registros)
#    Procesados 150/299 archivos... (748547 registros)
#    Procesados 160/299 archivos... (879780 registros)
#    Procesados 170/299 archivos... (963445 registros)
#    Procesados 180/299 archivos... (973292 registros)
#    Procesados 190/299 archivos... (1046013 registros)
#    Procesados 200/299 archivos... (1186433 registros)
#    Procesados 210/299 archivos... (1287225 registros)
#    Procesados 220/299 archivos... (1303187 registros)
#    Procesados 230/299 archivos... (1346843 registros)
#    Procesados 240/299 archivos... (1455708 registros)
#    Procesados 250/299 archivos... (1529425 registros)
#    Procesados 260/299 archivos... (1556838 registros)
#    Procesados 270/299 archivos... (1586109 registros)
#    Procesados 280/299 archivos... (1707925 registros)
#    Procesados 290/299 archivos... (1822764 registros)
# ✅ Cargados 1865407 registros de 299 archivos
# 💾 Memoria: 3346.54 MB
#
# ============================================================
# 🎯 Clientes cargados: 1,865,407 registros
# ============================================================

# %% [markdown]
# ## 🔍 3. Exploración Inicial
#
# Veamos qué información tenemos disponible.

# %%
# Ver primeras filas de APs
print("📡 MUESTRA DE ACCESS POINTS:")
df_aps.head()
# Out:
# 📡 MUESTRA DE ACCESS POINTS:
#   ap_deployment_mode ap_group  client_count cluster_id controller_name  \
# 0                IAP     None             2
# 1                IAP     None             9
# 2                IAP     None             3
# 3                IAP     None             0
# 4                IAP     None             0
#
#    cpu_utilization firmware_version gateway_cluster_id gateway_cluster_name  \
# 0                5   10.6.0.3_90581                 82       auto_group_229
# 1                7   10.6.0.3_90581                 82       auto_group_229
# 2                5   10.6.0.3_90581                 82       auto_group_229
# 3                4   10.6.0.3_90581                 82       auto_group_229
# 4                4   10.6.0.3_90581
#
#    group_name  ... site sleep_status  status    subnet_mask  swarm_id  \
# 0  Bellaterra  ...  UAB        False      Up  255.255.248.0
# 1  Bellaterra  ...  UAB        False      Up  255.255.252.0
# 2  Bellaterra  ...  UAB        False      Up  255.255.224.0
# 3  Bellaterra  ...  UAB        False      Up  255.255.255.0
# 4  Bellaterra  ...  UAB        False      Up  255.255.248.0
#
#    swarm_master      swarm_name    uptime down_reason           timestamp
# 0         False        AP-VET71   8666128         NaN 2025-01-21 09:41:31
# 1         False  AP-EXTBIBHUM01   5754534         NaN 2025-01-26 07:36:20
# 2         False       AP-LLET32  11697044         NaN 2025-04-02 09:56:41
# 3         False       AP-GTIP12   1124429         NaN 2025-04-02 09:57:02
# 4         False       AP-DRET14    110841         NaN 2025-04-01 15:17:14
#
# [5 rows x 33 columns]

# %%
# Ver primeras filas de Clientes
print("📱 MUESTRA DE CLIENTES:")
df_clients.head()
# Out:
# 📱 MUESTRA DE CLIENTES:
#   associated_device associated_device_mac associated_device_name  \
# 0   AP_8e2d9933ec92       AP_5cdc80c05afc              AP-CEDU26
# 1   AP_f6e291deb8b9       AP_b509bd7bc558               AP-VET49
# 2   AP_875979a461af       AP_e8c7358799e2              AP-LLET39
# 3   AP_332aab2f3da0       AP_35f1fd725406            AP-SAB-S239
# 4   AP_332aab2f3da0       AP_35f1fd725406            AP-SAB-S239
#
#   authentication_type  band       channel client_category client_type  \
# 0  MAC Authentication   5.0  100 (20 MHz)     SmartDevice    WIRELESS
# 1  MAC Authentication   2.4    1 (20 MHz)        Computer    WIRELESS
# 2  MAC Authentication   2.4    1 (20 MHz)        Computer    WIRELESS
# 3  MAC Authentication   5.0   44 (20 MHz)     SmartDevice    WIRELESS
# 4  MAC Authentication   5.0   44 (20 MHz)     SmartDevice    WIRELESS
#
#   connected_device_type                  connection  ... swarm_id  \
# 0                    AP           802.11ac, 802.11v  ...
# 1                    AP                         NaN  ...
# 2                    AP  802.11gn, 802.11k, 802.11v  ...      NaN
# 3                    AP  802.11ac, 802.11k, 802.11v  ...
# 4                    AP  802.11ac, 802.11k, 802.11v  ...
#
#           user_role           username    vlan failure_reason  usage  \
# 0               UAB  USER_87e3ddea248c  VLAN_A            NaN    NaN
# 1  conv_authenticad  USER_94894477ff4b  VLAN_A            NaN    NaN
# 2  conv_authenticad  USER_b3ed96b2b8f7  VLAN_A            NaN    NaN
# 3  conv_authenticad  USER_744af19bbca3  VLAN_A            NaN    NaN
# 4  conv_authenticad  USER_96645ec9c9d2  VLAN_A            NaN    NaN
#
#                 timestamp  hour day_of_week        date
# 0 2025-04-02 09:56:27.000   9.0   Wednesday  2025-04-02
# 1 2025-04-02 19:52:24.927  19.0   Wednesday  2025-04-02
# 2 2025-04-02 14:06:38.628  14.0   Wednesday  2025-04-02
# 3 2025-04-02 03:05:49.183   3.0   Wednesday  2025-04-02
# 4 2025-03-28 13:29:39.000  13.0      Friday  2025-03-28
#
# [5 rows x 46 columns]

# %%
# Información del dataset de APs
print_dataset_summary(df_aps, "Access Points")
# Out:
# ============================================================
# 📊 RESUMEN: Access Points
# ============================================================
#
# 🔢 Registros totales: 1,099,441
# 📝 Columnas: 33
# 💾 Memoria: 1471.86 MB
#
# 📅 Rango temporal:
#    Inicio: 2024-10-23 16:52:06
#    Fin:    2025-04-10 15:10:48
#    Días:   168
#
# 📋 Columnas disponibles:
#    • ap_deployment_mode             (100.0% completo)
#    • ap_group                       ( 26.2% completo)
#    • client_count                   (100.0% completo)
#    • cluster_id                     (100.0% completo)
#    • controller_name                (100.0% completo)
#    • cpu_utilization                (100.0% completo)
#    • firmware_version               (100.0% completo)
#    • gateway_cluster_id             (100.0% completo)
#    • gateway_cluster_name           (100.0% completo)
#    • group_name                     (100.0% completo)
#    ... y 23 columnas más
#
# ============================================================

# %%
# Información del dataset de Clientes
print_dataset_summary(df_clients, "Clientes")
# Out:
# ============================================================
# 📊 RESUMEN: Clientes
# ============================================================
#
# 🔢 Registros totales: 1,865,407
# 📝 Columnas: 46
# 💾 Memoria: 3548.53 MB
#
# 📅 Rango temporal:
#    Inicio: 2025-03-28 12:08:19.808000
#    Fin:    2025-04-10 20:59:53
#    Días:   13
#
# 📋 Columnas disponibles:
#    • associated_device              (100.0% completo)
#    • associated_device_mac          (100.0% completo)
#    • associated_device_name         (100.0% completo)
#    • authentication_type            ( 98.4% completo)
#    • band                           ( 96.5% completo)
#    • channel                        ( 96.5% completo)
#    • client_category                ( 97.6% completo)
#    • client_type                    (100.0% completo)
#    • connected_device_type          (100.0% completo)
#    • connection                     ( 95.0% completo)
#    ... y 36 columnas más
#
# ============================================================

# %% [markdown]
# ## 📊 4. Estadísticas Básicas
#
# ### 4.1 Access Points

# %%
# Número de APs únicos
unique_aps = df_aps['name'].nunique()
print(f"📡 APs únicos en el campus: {unique_aps}")

# Estado de los APs
print("\n🔌 Estado de los APs:")
print(df_aps['status'].value_counts())

# APs más populares (por número de clientes)
print("\n👥 Top 10 APs por número de clientes conectados:")
top_aps = df_aps.nlargest(10, 'client_count')[['name', 'client_count', 'status']]
print(top_aps)
# Out:
# 📡 APs únicos en el campus: 1144
#
# 🔌 Estado de los APs:
# status
# Up      1086194
# Down      13247
# Name: count, dtype: int64
#
# 👥 Top 10 APs por número de clientes conectados:
#                name  client_count status
# 238144  AP-BIBCIE01           159     Up
# 237002  AP-BIBCIE01           158     Up
# 239286  AP-BIBCIE01           158     Up
# 242712  AP-BIBCIE01           158     Up
# 230150  AP-BIBCIE01           156     Up
# 241570  AP-BIBCIE01           156     Up
# 231292  AP-BIBCIE01           154     Up
# 92360   AP-BIBCIE01           153     Up
# 234718  AP-BIBCIE01           153     Up
# 243854  AP-BIBCIE01           153     Up

# %% [markdown]
# ### 4.2 Clientes/Dispositivos

# %%
# Dispositivos únicos
unique_devices = df_clients['macaddr'].nunique()
print(f"📱 Dispositivos únicos: {unique_devices:,}")

# Tipos de red
print("\n🌐 Distribución por tipo de red:")
print(df_clients['network'].value_counts())

# Sistemas operativos
print("\n💻 Top 10 sistemas operativos:")
print(df_clients['os_type'].value_counts().head(10))

# Categorías de dispositivos
print("\n📦 Categorías de dispositivos:")
print(df_clients['client_category'].value_counts())
# Out:
# 📱 Dispositivos únicos: 69,369
#
# 🌐 Distribución por tipo de red:
# network
# UAB         1508530
# eduroam      343139
# IdC           10586
# IdC5GHz         886
# eduroamt          1
# Name: count, dtype: int64
#
# 💻 Top 10 sistemas operativos:
# os_type
# Apple iOS Device    537035
# Windows 8/10/11     408275
# Android             357824
# Mac OS              239871
# Apple iPhone         57450
# Samsung Android      47152
# Xiaomi Device        37899
# --                   35383
# Windows              25028
# Apple iPad           15711
# Name: count, dtype: int64
#
# 📦 Categorías de dispositivos:
# client_category
# SmartDevice                   1072611
# Computer                       695468
# Home Audio/Video Equipment      18695
# Printer                         10665
# Router                           9221
# Generic                          6301
# IoT                              5572
# Embedded                         1288
# Game Console                      760
# Monitoring Devices                374
# Lighting                          344
# Medical Device                    171
# Audio/Video Devices                 9
# Name: count, dtype: int64

# %% [markdown]
# ## 📈 5. Visualizaciones Básicas
#
# ### 5.1 Zonas "Hotspot" - APs más utilizados

# %%
# Top 15 APs más utilizados
top_aps_usage = df_clients['associated_device_name'].value_counts().head(15)

plt.figure(figsize=(12, 6))
top_aps_usage.plot(kind='barh', color='steelblue')
plt.title('📡 Top 15 Access Points Más Utilizados', fontsize=16, fontweight='bold')
plt.xlabel('Número de Conexiones', fontsize=12)
plt.ylabel('Access Point', fontsize=12)
plt.gca().invert_yaxis()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\n🔥 El AP más usado es: {top_aps_usage.index[0]} con {top_aps_usage.values[0]:,} conexiones")
# Out:
# 🔥 El AP más usado es: AP-BIBSOC08 con 15,454 conexiones

# %% [markdown]
# ### 5.2 Patrones Temporales - Actividad por Hora

# %%
# Actividad por hora del día
hourly_activity = df_clients.groupby('hour').size()

plt.figure(figsize=(14, 6))
plt.plot(hourly_activity.index, hourly_activity.values, marker='o', linewidth=2, markersize=8, color='coral')
plt.fill_between(hourly_activity.index, hourly_activity.values, alpha=0.3, color='coral')
plt.title('⏰ Dispositivos Conectados por Hora del Día', fontsize=16, fontweight='bold')
plt.xlabel('Hora del Día (0-23)', fontsize=12)
plt.ylabel('Número de Dispositivos', fontsize=12)
plt.xticks(range(0, 24))
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# Identificar hora pico
peak_hour = hourly_activity.idxmax()
peak_devices = hourly_activity.max()
print(f"\n🕐 Hora pico: {peak_hour}:00 con {peak_devices:,} dispositivos conectados")
# Out:
# 🕐 Hora pico: 9.0:00 con 308,252 dispositivos conectados

# %% [markdown]
# ### 5.3 Distribución de Calidad de Señal

# %%
# Distribución de signal_strength (1-5)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico 1: Signal Strength (1-5)
signal_counts = df_clients['signal_strength'].value_counts().sort_index()
axes[0].bar(signal_counts.index, signal_counts.values, color='seagreen', alpha=0.7)
axes[0].set_title('📶 Distribución de Calidad de Señal (1-5)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Signal Strength (1=peor, 5=mejor)', fontsize=11)
axes[0].set_ylabel('Número de Dispositivos', fontsize=11)
axes[0].set_xticks([1, 2, 3, 4, 5])
axes[0].grid(axis='y', alpha=0.3)

# Gráfico 2: Signal dB (histograma)
axes[1].hist(df_clients['signal_db'].dropna(), bins=30, color='royalblue', alpha=0.7, edgecolor='black')
axes[1].set_title('📊 Distribución de Señal (dBm)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Señal (dBm)', fontsize=11)
axes[1].set_ylabel('Frecuencia', fontsize=11)
axes[1].axvline(x=-60, color='red', linestyle='--', label='Umbral débil (-60 dBm)')
axes[1].legend()
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Estadísticas
avg_signal = df_clients['signal_db'].mean()
weak_signal = (df_clients['signal_db'] < -60).sum()
pct_weak = (weak_signal / len(df_clients)) * 100

print(f"\n📡 Señal promedio: {avg_signal:.1f} dBm")
print(f"⚠️  Dispositivos con señal débil (<-60 dBm): {weak_signal:,} ({pct_weak:.1f}%)")
# Out:
# 📡 Señal promedio: -61.5 dBm
# ⚠️  Dispositivos con señal débil (<-60 dBm): 733,905 (39.3%)

# %% [markdown]
# ### 5.4 Tipos de Red (UAB vs eduroam)

# %%
# Distribución por tipo de red
network_counts = df_clients['network'].value_counts()

plt.figure(figsize=(8, 8))
colors = ['#3498db', '#e74c3c']
plt.pie(network_counts.values, labels=network_counts.index, autopct='%1.1f%%',
        startangle=90, colors=colors, textprops={'fontsize': 14, 'weight': 'bold'})
plt.title('🌐 Distribución por Tipo de Red', fontsize=16, fontweight='bold')
plt.axis('equal')
plt.tight_layout()
plt.show()

print("\n📊 Desglose por red:")
for network, count in network_counts.items():
    pct = (count / len(df_clients)) * 100
    print(f"   {network}: {count:,} dispositivos ({pct:.1f}%)")
# Out:
# 📊 Desglose por red:
#    UAB: 1,508,530 dispositivos (80.9%)
#    eduroam: 343,139 dispositivos (18.4%)
#    IdC: 10,586 dispositivos (0.6%)
#    IdC5GHz: 886 dispositivos (0.0%)
#    eduroamt: 1 dispositivos (0.0%)

# %% [markdown]
# ### 5.5 Bandas WiFi (2.4 GHz vs 5 GHz)

# %%
# Distribución por banda
band_counts = df_clients['band'].value_counts().sort_index()
band_labels = {2.4: '2.4 GHz', 5: '5 GHz', 6: '6 GHz'}

plt.figure(figsize=(10, 6))
colors_band = ['#f39c12', '#9b59b6', '#1abc9c']
bars = plt.bar([band_labels.get(x, str(x)) for x in band_counts.index],
               band_counts.values, color=colors_band[:len(band_counts)], alpha=0.8)
plt.title('📻 Distribución por Banda WiFi', fontsize=16, fontweight='bold')
plt.xlabel('Banda', fontsize=12)
plt.ylabel('Número de Dispositivos', fontsize=12)
plt.grid(axis='y', alpha=0.3)

# Añadir valores encima de las barras
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}', ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎯 6. Insights y Conclusiones (Sobre las Samples)
#
# Basándote en las visualizaciones anteriores, responde:

# %% [markdown]
# **1. ¿Cuál es el AP más utilizado? ¿En qué edificio está?**
#
# ```
# AP CEDU 33. Se encuentra en ...
# ```
#
# **2. ¿A qué hora hay más actividad? ¿Por qué crees que es?**
#
# ```
# Por lo que vemos a las Samples a las 9, aunque hay sesgo debido a que faltan datos.
# ```
#
# **3. ¿Qué porcentaje de dispositivos tiene señal débil?**
#
# ```
# 41,9%
# ```
#
# **4. ¿Cuál es la red más utilizada (UAB o eduroam)?**
#
# ```
# UAB, con un 82,2 %
# ```
#
# **5. ¿Qué banda WiFi es más popular (2.4 o 5 GHz)? ¿Por qué?**
#
# ```
# La de 5 GHZ, ofrece más velocidad ya que los canales son más anchos.
# ```

# %% [markdown]
# ## 🚀 7. Próximos Pasos
#
# ¡Felicidades! Has completado el análisis básico. Ahora puedes:
#
# ### Ideas para Expandir tu Análisis:
#
# 1. **Cargar más datos:** Cambia `max_files=100` o `max_files=None` para todo el dataset
#
# 2. **Análisis por edificio:**
#    - Extraer el código del edificio del nombre del AP (ej: AP-VET71 → VET)
#    - Comparar actividad entre edificios
#
# 3. **Análisis temporal más profundo:**
#    - Comparar días laborables vs fines de semana
#    - Identificar patrones semanales
#
# 4. **Problemas de conectividad:**
#    - Identificar APs con peor señal
#    - Analizar zonas problemáticas
#
# 5. **Dashboard interactivo:**
#    - Usar Plotly para gráficos interactivos
#    - Crear filtros por fecha/hora/edificio
#
# ### ¿Listo para el siguiente nivel?
#
# 👉 Continúa con: **`02_intermediate_mobility.ipynb`**
#
# ---
#
# **🏴‍☠️ UAB THE HACK! 2025 - ¡Buena suerte! 🚀**
